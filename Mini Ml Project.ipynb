# %% [markdown]
# # Day 14 – End-to-End Mini Machine Learning Project
#
# ## Introduction
# An end-to-end Machine Learning project combines all the steps learned so far.
# It shows how raw data is transformed into predictions using a complete ML workflow.
#
# This project helps in understanding how individual concepts work together in real-world scenarios.
#
# ---
#
# ## Project Workflow
# The complete Machine Learning workflow includes:
# 1. Problem understanding
# 2. Data collection
# 3. Data preprocessing
# 4. Feature selection
# 5. Model selection
# 6. Model training
# 7. Model evaluation
# 8. Prediction
#
# ---
#
# ## Problem Statement
# Predict the marks of a student based on the number of study hours using a Machine Learning model.
#
# ---
#
# ## Tools and Libraries Used
# - Python
# - Pandas
# - NumPy
# - Scikit-learn
#
# ---
#
# ## Importance of End-to-End Projects
# End-to-end projects help in:
# - Understanding real-world ML workflows
# - Applying theoretical concepts practically
# - Building confidence in ML development
# - Preparing for ML interviews and jobs
#
# ---
#
# ## Conclusion
# End-to-end Machine Learning projects are essential for becoming a Machine Learning Engineer.
# They bridge the gap between theory and real-world application.

# %% [markdown]
# #### 1. Importing Required Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### 2. Creating The Dataset

# %%
data = {
    "StudyHours": [1, 2, 3, 4, 5, 6],
    "Marks": [35, 45, 60, 70, 80, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    StudyHours  Marks
# 0           1     35
# 1           2     45
# 2           3     60
# 3           4     70
# 4           5     80
# 5           6     90

# %% [markdown]
# #### 3. Splitting Features and Target

# %%
X = df[["StudyHours"]]
y = df["Marks"]
